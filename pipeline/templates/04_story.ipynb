# %% [markdown]
# # The Story
#
# Final report notebook. This is the published artifact — interactive
# Plotly charts, narrative prose, and a clear argument.
#
# **Exported to HTML** in `reports/` for sharing.
#
# ---

# %%
from pathlib import Path

import pandas as pd
import plotly.express as px
import plotly.graph_objects as go
from pipeline.config import load_config, get_data_processed_dir

PROJECT_NAME = "qol-immigration"  # UPDATE per project

config = load_config(PROJECT_NAME)
processed_dir = get_data_processed_dir(config)

parquet_files = sorted(processed_dir.glob("*.parquet"))
datasets = {pf.stem: pd.read_parquet(pf) for pf in parquet_files}

# %% [markdown]
# ## Headline
#
# *(Write the headline and opening hook here. What is the single most
# compelling takeaway from this study?)*

# %% [markdown]
# ## The Setup
#
# *(Context: what question are we asking, and why does it matter?)*

# %%
# Setup chart — e.g. the big-picture trend that frames the question
# fig = px.line(...)
# fig.show()

# %% [markdown]
# ## Finding 1
#
# *(Narrative for the first key finding. What did we see? Why does it matter?)*

# %%
# Finding 1 chart
# fig = px.scatter(...)
# fig.show()

# %% [markdown]
# ## Finding 2
#
# *(Narrative for the second key finding. How does it build on Finding 1?)*

# %%
# Finding 2 chart
# fig = px.bar(...)
# fig.show()

# %% [markdown]
# ## Finding 3
#
# *(Narrative for the third key finding. The twist, the nuance, or the
# most provocative angle.)*

# %%
# Finding 3 chart
# fig = px.choropleth(...)
# fig.show()

# %% [markdown]
# ## The Takeaway
#
# *(What does this all mean? What should the reader walk away with?
# State the conclusion clearly, acknowledge limitations, and point
# toward what should be investigated next.)*

# %% [markdown]
# ## Methodology & Limitations
#
# *(Brief description of data sources, analytical approach, and stated
# limitations. Link to the full descriptive and findings notebooks for
# transparency.)*
#
# - Data sources: *(list)*
# - Time range: *(range)*
# - Geographic granularity: *(level)*
# - Analytical approach: *(summary)*
# - Key limitations: *(list)*
